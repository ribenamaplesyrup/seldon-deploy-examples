# %%
from seldon_core.seldon_client import SeldonClient
from PIL import Image
import numpy as np


endpoint = "127.0.0.1:9001"

# %%
image = Image.open("input/image2.jpg").convert('RGB')
# a NumPy copy for OpenCV functions
image_array = np.array(image)
# convert to OpenCV BGR color format
# image_array = cv2.cvtColor(image_array, cv2.COLOR_RGB2BGR)

# %%
X = image_array.tolist()

# %%
sc = SeldonClient(microservice_endpoint=endpoint)
response = sc.microservice(
   json_data = X,
   method='predict'
)

# print(response.response)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ce919d0b3c10> in <module>
#       1 sc = SeldonClient(microservice_endpoint=endpoint)
# ----> 2 response = sc.microservice(
#       3    json_data = X,
#       4    method='predict'
#       5 )
#
# ~\miniconda3\envs\pytorch\lib\site-packages\seldon_core\seldon_client.py in microservice(self, gateway, transport, deployment_name, payload_type, gateway_endpoint, microservice_endpoint, method, shape, namespace, data, datas, ndatas, bin_data, str_data, json_data, custom_data, names)
#     692                 or k["method"] == "route"
#     693             ):
# --> 694                 return microservice_api_rest_seldon_message(**k)
#     695             elif k["method"] == "aggregate":
#     696                 return microservice_api_rest_aggregate(**k)
#
# ~\miniconda3\envs\pytorch\lib\site-packages\seldon_core\seldon_client.py in microservice_api_rest_seldon_message(method, microservice_endpoint, shape, data, payload_type, bin_data, str_data, json_data, names, **kwargs)
#     849         datadef = array_to_grpc_datadef(payload_type, data, names=names)
#     850         request = prediction_pb2.SeldonMessage(data=datadef)
# --> 851     payload = seldon_message_to_json(request)
#     852     response_raw = requests.post(
#     853         "http://" + microservice_endpoint + "/" + method,
#
# ~\miniconda3\envs\pytorch\lib\site-packages\seldon_core\utils.py in seldon_message_to_json(message_proto)
#     135        JSON Dict
#     136     """
# --> 137     message_json = json_format.MessageToJson(message_proto)
#     138     message_dict = json.loads(message_json)
#     139     return message_dict
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in MessageToJson(message, including_default_value_fields, preserving_proto_field_name, indent, sort_keys, use_integers_for_enums, descriptor_pool, float_precision)
#     135       descriptor_pool,
#     136       float_precision=float_precision)
# --> 137   return printer.ToJsonString(message, indent, sort_keys)
#     138
#     139
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in ToJsonString(self, message, indent, sort_keys)
#     202
#     203   def ToJsonString(self, message, indent, sort_keys):
# --> 204     js = self._MessageToJsonObject(message)
#     205     return json.dumps(js, indent=indent, sort_keys=sort_keys)
#     206
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _MessageToJsonObject(self, message)
#     214       return methodcaller(_WKTJSONMETHODS[full_name][0], message)(self)
#     215     js = {}
# --> 216     return self._RegularMessageToJsonObject(message, js)
#     217
#     218   def _RegularMessageToJsonObject(self, message, js):
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _RegularMessageToJsonObject(self, message, js)
#     249           js[name] = self._FieldToJsonObject(field, value)
#     250         else:
# --> 251           js[name] = self._FieldToJsonObject(field, value)
#     252
#     253       # Serialize default value if including_default_value_fields is True.
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _FieldToJsonObject(self, field, value)
#     283     """Converts field value according to Proto3 JSON Specification."""
#     284     if field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_MESSAGE:
# --> 285       return self._MessageToJsonObject(value)
#     286     elif field.cpp_type == descriptor.FieldDescriptor.CPPTYPE_ENUM:
#     287       if self.use_integers_for_enums:
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _MessageToJsonObject(self, message)
#     212       return self._WrapperMessageToJsonObject(message)
#     213     if full_name in _WKTJSONMETHODS:
# --> 214       return methodcaller(_WKTJSONMETHODS[full_name][0], message)(self)
#     215     js = {}
#     216     return self._RegularMessageToJsonObject(message, js)
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _ValueMessageToJsonObject(self, message)
#     358       return None
#     359     if which == 'list_value':
# --> 360       return self._ListValueMessageToJsonObject(message.list_value)
#     361     if which == 'struct_value':
#     362       value = message.struct_value
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _ListValueMessageToJsonObject(self, message)
#     368   def _ListValueMessageToJsonObject(self, message):
#     369     """Converts ListValue message according to Proto3 JSON Specification."""
# --> 370     return [self._ValueMessageToJsonObject(value)
#     371             for value in message.values]
#     372
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in <listcomp>(.0)
#     368   def _ListValueMessageToJsonObject(self, message):
#     369     """Converts ListValue message according to Proto3 JSON Specification."""
# --> 370     return [self._ValueMessageToJsonObject(value)
#     371             for value in message.values]
#     372
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _ValueMessageToJsonObject(self, message)
#     358       return None
#     359     if which == 'list_value':
# --> 360       return self._ListValueMessageToJsonObject(message.list_value)
#     361     if which == 'struct_value':
#     362       value = message.struct_value
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _ListValueMessageToJsonObject(self, message)
#     368   def _ListValueMessageToJsonObject(self, message):
#     369     """Converts ListValue message according to Proto3 JSON Specification."""
# --> 370     return [self._ValueMessageToJsonObject(value)
#     371             for value in message.values]
#     372
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in <listcomp>(.0)
#     368   def _ListValueMessageToJsonObject(self, message):
#     369     """Converts ListValue message according to Proto3 JSON Specification."""
# --> 370     return [self._ValueMessageToJsonObject(value)
#     371             for value in message.values]
#     372
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _ValueMessageToJsonObject(self, message)
#     358       return None
#     359     if which == 'list_value':
# --> 360       return self._ListValueMessageToJsonObject(message.list_value)
#     361     if which == 'struct_value':
#     362       value = message.struct_value
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _ListValueMessageToJsonObject(self, message)
#     368   def _ListValueMessageToJsonObject(self, message):
#     369     """Converts ListValue message according to Proto3 JSON Specification."""
# --> 370     return [self._ValueMessageToJsonObject(value)
#     371             for value in message.values]
#     372
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in <listcomp>(.0)
#     368   def _ListValueMessageToJsonObject(self, message):
#     369     """Converts ListValue message according to Proto3 JSON Specification."""
# --> 370     return [self._ValueMessageToJsonObject(value)
#     371             for value in message.values]
#     372
#
# ~\miniconda3\envs\pytorch\lib\site-packages\google\protobuf\json_format.py in _ValueMessageToJsonObject(self, message)
#     362       value = message.struct_value
#     363     else:
# --> 364       value = getattr(message, which)
#     365     oneof_descriptor = message.DESCRIPTOR.fields_by_name[which]
#     366     return self._FieldToJsonObject(oneof_descriptor, value)
#
# KeyboardInterrupt:
